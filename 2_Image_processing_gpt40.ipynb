# %% [markdown]
# **Image Processing**
#
# GPT-4o can directly process images and take intelligent actions based on the image. We can provide images in two formats:
#
# Base64 Encoded
#
# URL
# Let's first view the image we'll use, then try sending this image as both Base64 and as a URL link to the API

# %%
# !pip install --upgrade openai --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.7 MB/s eta 0:00:00

# %%
from google.colab import userdata
OPEN_AI_KEY=userdata.get('opeaikey4o')

# %%
from openai import OpenAI


## Set the API key and model name
MODEL="gpt-4o"
client = OpenAI(api_key=OPEN_AI_KEY)

# %%
from IPython.display import Image, display, Audio, Markdown
import base64

IMAGE_PATH = "square.jpg"

# Preview image for context
display(Image(IMAGE_PATH))

# %%
# Open the image file and encode it as a base64 string
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

base64_image = encode_image(IMAGE_PATH)

response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant that responds in Markdown. Help me with my math homework!"},
        {"role": "user", "content": [
            {"type": "text", "text": "What's the area of the square?"},
            {"type": "image_url", "image_url": {
                "url": f"data:image/jpg;base64,{base64_image}"}
            }
        ]}
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# To find the area of a square, you can use the formula:
#
# \[ \text{Area} = \text{side}^2 \]
#
# Given that each side of the square is 20 cm, the area is:
#
# \[ \text{Area} = 20 \, \text{cm} \times 20 \, \text{cm} = 400 \, \text{cm}^2 \]
#
# So, the area of the square is \( 400 \, \text{cm}^2 \).
